# %% [markdown]
# ### Here we will clean up the data

# %%
import pandas as pd
from IPython.display import display

# %% [markdown]
# ### Problem 3. Data cleaning and preprocessing (1 point)
# This should be self-explanatory. In an appropriate notebook (probably different than your previous one), explore different ways to clean and preprocess the dataset.
#
# This is still part of your research. That is, don't be afraid to _try out different approaches to the same problem_. E.g., if you have a lot of missing values, you may not know right away how to handle them. Experimenting with several approaches will give you a better indication what works well for your data and goals.

# %% [markdown]
# Let's begin...

# %%
astma = pd.read_csv("../data/asthma_disease_data.csv")
pd.set_option('display.max_columns', None)

astma.DoctorInCharge.value_counts()
# We see that all doctors in charge are confidential, so they are useless to us.

astma.drop(columns=["DoctorInCharge"], inplace=True)

astma[(astma.Gender != 1) & (astma.Gender != 0)] # Just in case lol

# For more clarity, I will map the nomenclature columns to their category names.
astma.Gender = astma.Gender.astype('category').map({0: 'Male', 1: 'Female'})
astma.Ethnicity = astma.Ethnicity.astype('category').map({0: 'Caucasian', 1: 'African American', 2: 'Asian', 3: 'Other'})
astma.EducationLevel = astma.EducationLevel.astype('category').map({0: 'None', 1: 'High School', 2: 'Bachelor''s', 3: 'Higher'})

astma.describe()
# The rest of the data seems to be good, no separation from the dataset description in kaggle.
# Out:
#          PatientID          Age          BMI      Smoking  PhysicalActivity  \
# count  2392.000000  2392.000000  2392.000000  2392.000000       2392.000000
# mean   6229.500000    42.137960    27.244877     0.141722          5.051786
# std     690.655244    21.606655     7.201628     0.348838          2.903574
# min    5034.000000     5.000000    15.031803     0.000000          0.001740
# 25%    5631.750000    23.000000    20.968313     0.000000          2.578333
# 50%    6229.500000    42.000000    27.052202     0.000000          5.016881
# 75%    6827.250000    61.000000    33.555903     0.000000          7.540234
# max    7425.000000    79.000000    39.985611     1.000000          9.995809
#
#        DietQuality  SleepQuality  PollutionExposure  PollenExposure  \
# count  2392.000000   2392.000000        2392.000000     2392.000000
# mean      5.022867      7.019012           5.013030        5.114221
# std       2.909980      1.732475           2.935605        2.893088
# ...

# %%
display(astma)
# Out:
#       PatientID  Age  Gender         Ethnicity EducationLevel        BMI  \
# 0          5034   63    Male  African American           None  15.848744
# 1          5035   26  Female             Asian      Bachelors  22.757042
# 2          5036   57    Male             Asian    High School  18.395396
# 3          5037   40  Female             Asian    High School  38.515278
# 4          5038   61    Male         Caucasian         Higher  19.283802
# ...         ...  ...     ...               ...            ...        ...
# 2387       7421   43  Female         Caucasian      Bachelors  29.059613
# 2388       7422   18  Female         Caucasian    High School  20.740850
# 2389       7423   54    Male             Other      Bachelors  37.079560
# 2390       7424   46  Female         Caucasian      Bachelors  23.444712
# 2391       7425   26  Female         Caucasian           None  28.123021
#
#       Smoking  PhysicalActivity  DietQuality  SleepQuality  PollutionExposure  \
# ...
